# %% [markdown]
# # **The Navier-Stokes equations - ALE**
# **Johan Hoffman**

# %% [markdown]
# # **Abstract**

# %% [markdown]
# This short report show an example on how to use FEniCS to solve the Navier-Stokes equations using an ALE method, which is used in the course DD2365 Advanced Computation in Fluid Mechanics, at the KTH Royal Institute of Technology. We consider two cyclic movements  and deformations of cylinders in a 2D flow across a rectangular channel, by analyzing the impact of the movement over the drag and lift forces. Based on our analysis, we design a flappy wing that must maximize average lift and minimize drag.
#
# [DD2365 course website.](https://www.kth.se/social/course/DD2365/)

# %% [markdown]
# # **About the code**

# %%
"""This program is an example file for the course"""
"""DD2365 Advanced Computation in Fluid Mechanics, """
"""KTH Royal Institute of Technology, Stockholm, Sweden."""

# Copyright (C) 2021 Johan Hoffman (jhoffman@kth.se)

# This file is part of the course DD2365 Advanced Computation in Fluid Mechanics
# KTH Royal Institute of Technology, Stockholm, Sweden
#
# This is free software: you can redistribute it and/or modify
# it under the terms of the GNU Lesser General Public License v2.

# This template is maintained by Johan Hoffman
# Please report problems to jhoffman@kth.se
# Out:
# 'KTH Royal Institute of Technology, Stockholm, Sweden.'

# %% [markdown]
# # **Set up environment**

# %%
# Load neccessary modules.
from google.colab import files

import numpy as np
import time

# Install FEniCS (this may take a long time)
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin
    
from dolfin import *; from mshr import *

import dolfin.common.plotting as fenicsplot

from matplotlib import pyplot as plt

# %% [markdown]
# # **Introduction**

# %% [markdown]
# The Navier-Stokes equations take the form
#
# $\dot u + (u\cdot \nabla)u + \nabla p -\Delta u = f,\quad \nabla \cdot u=0,$
#
# together with suitable initial and boundary conditions.
#
# Here we present a FEniCS implementation of a stabilized space-time Arbitrary Lagrangian-Eulerian (ALE) finite element method to solve the Navier-Stokes equations in 2D. The solution is visualized using FEniCS plotting functions, and is also exported as pvd-files which can be visualized in Paraview.
#
# We seek a finite element approximation $(u,p)\in V\times Q$ such that
#
# $(\dot u + ((u-m)\cdot \nabla)u, v) - (p,\nabla \cdot v) + (\nu \nabla u,\nabla v) + (\nabla \cdot u, q) + SD(u,p;v,q) = (f,v),$
#
# for all test functions $(v,q) \in \hat V\times \hat Q$, where $SD(u,p;v,q)$ is a residual based stabilization term. The mesh velocity is denoted by m.
#
# We present an example of flow past a circular cylinder, for which we compute the force on the surface of the cylinder $\Gamma$ in the direction $\phi$, by Green's formula:
#
# $
# F(u,p,\phi)= ~<\nu \nabla u\cdot n-pn, \Phi>_{\Gamma} ~=~(\dot u+(u\cdot \nabla)u, \Phi) + (\nu \nabla u,\nabla \Phi) - (p,\nabla \cdot\Phi)-(f,\Phi),
# $
#
# with $\Phi\in V$ a fuinction for which $\Phi\vert _{\Gamma}=\phi$ and $\Phi\vert_{\partial \Omega \setminus \Gamma}=0$. With $\phi=(1,0)$ we get the drag force $F_D$, and with $\phi=(0,1)$ the lift force $F_L$. The drag and lift coefficients are obtained by normalization,
#
# $
# c_D = \frac{2F_D}{\rho U^2D}, \quad c_L = \frac{2F_L}{\rho U^2D}
# $
#
# where $\rho$ is the density (here $\rho=1$), $U$ the characteristic velocity (here $U=1$), and $D$ the characteristic length scale (here $D$ is the diameter of the cylinder).
#
# The Reynolds number is defined as $Re=\frac{UD}{\nu}$
#
# To read more about how to use similar methods for more complex problems, see e.g.
#
# [Hoffman, Johan, et al. "Towards a parameter-free method for high reynolds number turbulent flow simulation based on adaptive finite element approximation." Computer Methods in Applied Mechanics and Engineering 288 (2015): 60-74.](https://www.sciencedirect.com/science/article/pii/S0045782514004836)

# %% [markdown]
# # **Method**

# %% [markdown]
# **Define domain and mesh**

# %%
# Define rectangular domain 
L = 4
H = 2

# Define circle
xc = 1.0
yc = 0.5*H
rc = 0.2

# Define subdomains (for boundary conditions)
class Left(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[0], 0.0) 

class Right(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[0], L)

class Lower(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[1], 0.0)

class Upper(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[1], H)
      
left = Left()
right = Right()
lower = Lower()
upper = Upper()

# Generate mesh (examples with and without a hole in the mesh) 
resolution = 32
#mesh = RectangleMesh(Point(0.0, 0.0), Point(L, H), L*resolution, H*resolution)
mesh = generate_mesh(Rectangle(Point(0.0,0.0), Point(L,H)) - Circle(Point(xc,yc),rc), resolution)

# Local mesh refinement (specified by a cell marker)
no_levels = 0
for i in range(0,no_levels):
  cell_marker = MeshFunction("bool", mesh, mesh.topology().dim())
  for cell in cells(mesh):
    cell_marker[cell] = False
    p = cell.midpoint()
    if p.distance(Point(xc, yc)) < 1.0:
        cell_marker[cell] = True
  mesh = refine(mesh, cell_marker)

# Define mesh functions (for boundary conditions)
boundaries = MeshFunction("size_t", mesh, mesh.topology().dim()-1)
boundaries.set_all(0)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
lower.mark(boundaries, 3)
upper.mark(boundaries, 4)

plt.figure()
plot(mesh)
plt.show()

# %% [markdown]
# **Define finite element approximation spaces**

# %%
# Generate finite element spaces (for velocity and pressure)
V = VectorFunctionSpace(mesh, "Lagrange", 1)
Q = FunctionSpace(mesh, "Lagrange", 1)

# Define trial and test functions 
u = TrialFunction(V)
p = TrialFunction(Q)
v = TestFunction(V)
q = TestFunction(Q)

# %% [markdown]
# **Define boundary conditions**

# %%
# Define boundary conditions 
class DirichletBoundaryLower(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[1], 0.0)

class DirichletBoundaryUpper(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[1], H)

class DirichletBoundaryLeft(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[0], 0.0) 

class DirichletBoundaryRight(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[0], L)

class DirichletBoundaryObjects(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and (not near(x[0], 0.0)) and (not near(x[0], L)) and (not near(x[1], 0.0)) and (not near(x[1], H))

dbc_lower = DirichletBoundaryLower()
dbc_upper = DirichletBoundaryUpper()
dbc_left = DirichletBoundaryLeft()
dbc_right = DirichletBoundaryRight()
dbc_objects = DirichletBoundaryObjects()

# Examples of time dependent and stationary inflow conditions
#uin = Expression('4.0*x[1]*(1-x[1])', element = V.sub(0).ufl_element())
#uin = Expression('1.0 + 1.0*fabs(sin(t))', element = V.sub(0).ufl_element(), t=0.0)
uin = 1.0
bcu_in0 = DirichletBC(V.sub(0), uin, dbc_left)
bcu_in1 = DirichletBC(V.sub(1), 0.0, dbc_left)
bcu_upp0 = DirichletBC(V.sub(0), 0.0, dbc_upper)
bcu_upp1 = DirichletBC(V.sub(1), 0.0, dbc_upper)
bcu_low0 = DirichletBC(V.sub(0), 0.0, dbc_lower)
bcu_low1 = DirichletBC(V.sub(1), 0.0, dbc_lower)
bcu_obj0 = DirichletBC(V.sub(0), 0.0, dbc_objects)
bcu_obj1 = DirichletBC(V.sub(1), 0.0, dbc_objects)

pin = Expression('5.0*fabs(sin(t))', element = Q.ufl_element(), t=0.0)
pout = 0.0
#bcp0 = DirichletBC(Q, pin, dbc_left) 
bcp1 = DirichletBC(Q, pout, dbc_right)

#bcu = [bcu_in0, bcu_in1, bcu_upp0, bcu_upp1, bcu_low0, bcu_low1, bcu_obj0, bcu_obj1]
bcu = [bcu_in0, bcu_in1, bcu_upp1, bcu_low1, bcu_obj0, bcu_obj1]
bcp = [bcp1]

# Define measure for boundary integration  
ds = Measure('ds', domain=mesh, subdomain_data=boundaries)

# %% [markdown]
# # **Results**

# %% [markdown]
# **Define flow parameters**

# %%
# Set viscosity
nu = 4.0e-3

# %% [markdown]
# **Define method parameters**

# %%
# Define iteration functions
# (u0,p0) solution from previous time step
# (u1,p1) linearized solution at present time step  
u0 = Function(V)
u1 = Function(V)
p0 = Function(Q)
p1 = Function(Q)

# Define mesh deformation w, mesh velocity = w/dt
amp_x = 0
amp_y = 1.0e-2
freq = 0.1
t = 0.0

# For moving cylinder 
#w = Expression(("amp_x*sin(2.0*pi*t*freq)*sin(pi*x[0]/L)","amp_y*sin(2.0*pi*t*freq-0.5*pi)*sin(pi*x[1]/H)"), L=L, H=H, t=t, amp_x=amp_x, amp_y=amp_y, freq=freq, element = V.ufl_element())

# For stationary cylinder
#w = Expression(("amp_x*sin(2.0*pi*t*freq)*sin(pi*x[0]/L)","amp_y*sin(2.0*pi*t*freq-0.5*pi)*sin(pi*x[1]*2/H)"), L=L, H=H, t=t, amp_x=amp_x, amp_y=amp_y, freq=freq, element = V.ufl_element())

# Flappy wing
amp_x = 2.0e-2
amp_y = 2.0e-2
freq = 0.2
w = Expression(("amp_x*sin(2.0*pi*t*freq)*sin(pi*x[0]/L)","amp_y*sin(2.0*pi*t*freq)*sin(pi*x[1]/H)"), L=L, H=H, t=t, amp_x=amp_x, amp_y=amp_y, freq=freq, element = V.ufl_element())


# Set parameters for nonlinear and lienar solvers 
num_nnlin_iter = 5 
prec = "amg" if has_krylov_solver_preconditioner("amg") else "default" 

# Time step length 
dt = 0.5*mesh.hmin()

# %% [markdown]
# **Define variational problem**

# %%
# Define variational problem

# Stabilization parameters
h = CellDiameter(mesh);
u_mag = sqrt(dot(u1,u1))
d1 = 1.0/sqrt((pow(1.0/dt,2.0) + pow(u_mag/h,2.0)))
d2 = h*u_mag

# Mean velocities for trapozoidal time stepping
um = 0.5*(u + u0)
um1 = 0.5*(u1 + u0)

# Momentum variational equation on residual form
Fu = inner((u - u0)/dt + grad(um)*(um1-w/dt), v)*dx - p1*div(v)*dx + nu*inner(grad(um), grad(v))*dx \
    + d1*inner((u - u0)/dt + grad(um)*(um1-w/dt) + grad(p1), grad(v)*(um1-w/dt))*dx + d2*div(um)*div(v)*dx 
au = lhs(Fu)
Lu = rhs(Fu)

# Continuity variational equation on residual form
Fp = d1*inner((u1 - u0)/dt + grad(um1)*(um1-w/dt) + grad(p), grad(q))*dx + div(um1)*q*dx 
ap = lhs(Fp)
Lp = rhs(Fp)

# %% [markdown]
# **Compute force on boundary**

# %%
# Define the direction of the drag force to be computed 
phi_x_1 = 1.0
phi_y_1 = 0.0

#psi_expression = Expression(("0.0","pow(x[0]-0.5,2.0) + pow(x[1]-1.0,2.0) - pow(0.2,2.0) < 1.e-5 ? 1. : 0."), element = V.ufl_element())
psi_expression_1 = Expression(("near(pow(x[0]-xc,2.0) + pow(x[1]-yc,2.0) - pow(rc,2.0), 0.0) ? phi_x : 0.","near(pow(x[0]-xc,2.0) + pow(x[1]-yc,2.0) - pow(rc,2.0), 0.0) ? phi_y : 0."), xc=xc, yc=yc, rc=rc, phi_x=phi_x_1, phi_y=phi_y_1, element = V.ufl_element())
psi_1 = interpolate(psi_expression_1, V)

Force_1 = inner((u1 - u0)/dt + grad(um1)*um1, psi_1)*dx - p1*div(psi_1)*dx + nu*inner(grad(um1), grad(psi_1))*dx

# Define the direction of the lift force to be computed 
phi_x_2 = 0.0
phi_y_2 = 1.0

#psi_expression = Expression(("0.0","pow(x[0]-0.5,2.0) + pow(x[1]-1.0,2.0) - pow(0.2,2.0) < 1.e-5 ? 1. : 0."), element = V.ufl_element())
psi_expression_2 = Expression(("near(pow(x[0]-xc,2.0) + pow(x[1]-yc,2.0) - pow(rc,2.0), 0.0) ? phi_x : 0.","near(pow(x[0]-xc,2.0) + pow(x[1]-yc,2.0) - pow(rc,2.0), 0.0) ? phi_y : 0."), xc=xc, yc=yc, rc=rc, phi_x=phi_x_2, phi_y=phi_y_2, element = V.ufl_element())
psi_2 = interpolate(psi_expression_2, V)

Force_2 = inner((u1 - u0)/dt + grad(um1)*um1, psi_2)*dx - p1*div(psi_2)*dx + nu*inner(grad(um1), grad(psi_2))*dx


#plt.figure()
#plot(psi, title="weight function psi")

# Force normalization
D = 2*rc
normalization = -2.0/D

# %% [markdown]
# **Set plotting variables and open export files**

# %%
# Open files to export solution to Paraview
file_u = File("results-NS/u.pvd")
file_p = File("results-NS/p.pvd")

# Set plot frequency
plot_time = 0
plot_freq = 20

# Force computation data 
drag_force_array = np.array(0.0)
drag_force_array = np.delete(drag_force_array, 0)
lift_force_array = np.array(0.0)
lift_force_array = np.delete(lift_force_array, 0)
time = np.array(0.0)
time = np.delete(time, 0)
start_sample_time = 1.0

# %% [markdown]
# **Time stepping algorithm**

# %%
# !rm results-NS/*

# Time stepping 
T = 30
t = dt

while t < T + DOLFIN_EPS:

    #s = 'Time t = ' + repr(t) 
    #print(s)

    pin.t = t
    #uin.t = t

    w.t = t 
    ALE.move(mesh, w)

    # Solve non-linear problem 
    k = 0
    while k < num_nnlin_iter: 
        
        # Assemble momentum matrix and vector 
        Au = assemble(au)
        bu = assemble(Lu)

        # Compute velocity solution 
        [bc.apply(Au, bu) for bc in bcu]
        [bc.apply(u1.vector()) for bc in bcu]
        solve(Au, u1.vector(), bu, "bicgstab", "default")

        # Assemble continuity matrix and vector
        Ap = assemble(ap) 
        bp = assemble(Lp)

        # Compute pressure solution 
        [bc.apply(Ap, bp) for bc in bcp]
        [bc.apply(p1.vector()) for bc in bcp]
        solve(Ap, p1.vector(), bp, "bicgstab", prec)

        # Compute force
        F_1 = assemble(Force_1)
        F_2 = assemble(Force_2)
        if (t > start_sample_time):
          drag_force_array = np.append(drag_force_array, normalization*F_1)
          lift_force_array = np.append(lift_force_array, normalization*F_2)
          time = np.append(time, t)

        k += 1

    if t > plot_time:     
        
        s = 'Time t = ' + repr(t) 
        print(s)
    
        # Save solution to file
        file_u << u1
        file_p << p1

        # Plot solution
        plt.figure()
        plot(u1, title="Velocity")

        plt.figure()
        plot(p1, title="Pressure")

        plt.figure()
        plot(mesh, title="Mesh")
        
        plot_time += T/plot_freq
        
        plt.show()

        plt.figure()
        plt.title("Drag force")
        plt.plot(time, drag_force_array)
        plt.show()

        plt.figure()
        plt.title("Lift force")
        plt.plot(time, lift_force_array)
        plt.show()

    # Update time step
    u0.assign(u1)
    t += dt

#!tar -czvf results-NS.tar.gz results-NS
#files.download('results-NS.tar.gz')

# %% [markdown]
# ## Oscillating cylinder ##
# ### Movement and deformation ###
# You can see here the movement and deformation of the cylinder through the deforming mesh.
#
# ![mov_mesh_low.png](data:image/png;base64,...)![mov_mesh_kmid.png](data:image/png;base64,...)![mov_mesh_high.png](data:image/png;base64,...)

# %% [markdown]
# The cylinder oscillate vertically from up to down, and the more it goes up and down from its reference height $y=1$, the more it is compressed. We therefore have a movement combined with a deformation.

# %% [markdown]
# ### Drag and lift forces plots###
#
# ![mov_lift_plot.png](data:image/png;base64,...)![mov_drag_plot.png](data:image/png;base64,...)

# %% [markdown]
# We can see above the drag and lift forces are cyclic as the movement described previously. The lift force is positive when the cylinder moves upwards, and negative when moving downwards. The peaks and downs are situated respectively at the peaks and down of the oscillation of the cylinder.
#
# Moreover, the drag being focused on the x-direction, it does not care if we are up and down in the motion, but rather focuses on our speed and deformation. As the compression is higher when the cylinder is at the tops and bottoms of oscillation, the drag is at a low, as the projected surface dragging the x-direction is smaller. Whereas the drag force is at a peak when the cylinder is not deformed at all, and there has a bigger dragging surface because not compressed. Therefore we count twice the number of peaks for the drag than for the lift force.

# %% [markdown]
# ## Static cylinder with vertical cyclic deformation ##
# ### Deformation ###
# You can see here the deformation period through the mesh deformation.
#
# ![fix_mesh_expa.png](data:image/png;base64,...)![fix_mesh_dmid.png](data:image/png;base64,...)![fix_mesh_comp.png](data:image/png;base64,...)

# %% [markdown]
# Now we focus on a static cylinder with a vertical deformation as we can see above, with compression and expansion cyclic phases.

# %% [markdown]
# ### Drag and lift forces plots ###
#
# ![fix_lift_plot.png](data:image/png;base64,...)![fix_drag_plot.png](data:image/png;base64,...)

# %% [markdown]
# We see above the drag and lift forces of the static cylinder. As expected the drag force is at a peak when the cylinder is expanded, whereas it is at a down when compressed.
#
# For the lift force it is a bit more tricky. It seems like during the expansion phase, the lift is negative, while during the compression phase, the lift is positive.

# %% [markdown]
# ## Flappy wing ##
# In order to design a good flappy wing, we need to maximize the lift and minimize the drag, which often need a trade-off. To minimize the drag, we can for instance compress the cylinder as much as possible or play with the x-velocity to go with the wind, in order to not to drag too much with the inflow fluid. Going against the wind would increase the drag.
# To maximize the lift and get a positive average lift, we must introduce assymetries in the wing movement. We can play on the lift area, so that the wing goes from bottom to top with a big flat surface on y-direction of the wing to lift as much as possible, and get a smaller or round surface on the y-direction when going down to decrease the negative lift contribution. Another way is also to go with the wind when going up and against when going down, which might work with some wing shapes. This is the solution we took into account.
# Here is the trade-off found after tuning the amplitude deformations and oscillation frequency.

# %% [markdown]
# ### Movement and deformation of wing ###
#
# You can see here the movement and deformation of the wing through mesh deformation.
#
# ![flap_mesh_3.png](data:image/png;base64,...)![flap_mesh_2.png](data:image/png;base64,...)![flap_mesh_1.png](data:image/png;base64,...)![flap_mesh_0.png](data:image/png;base64,...)

# %% [markdown]
# We can see above that we manage to get a trade-off with the properties of a good wind described previously and seem to work as desired, we indeed go with the wind when going up, and go against when going down (see figures above), so that because of the wing shape, the force due to going against the wind drags but also gives an extra lift to the wing, so that it is positive in average. Here are the results below.

# %% [markdown]
# ### Wing lift and drag forces plots ###
#
# ![flap_drag_plot.png](data:image/png;base64,...)![flap_lift_plot.png](data:image/png;base64,...)

# %% [markdown]
# We can see that the lift force is indeed positive on average, as expected, which is way better than the previous movements and deformations analyzed previously, with the oscillating and static cylinders. Also, the drag seems to be quite similar to the oscillating cylinder moving up and down, which was also ranging between 1 and 2.5. We do not even compare with the static cylinder that had a drag reaching almost 30 in drag magnitude.
# Because the wing seem to be efficient, we increased the oscillation frequency to $0.2$ to improve the lift rate over time.
# Therefore, we conclude we found a nice trade-off between lift and drag, by really improving the lift when compared with previous cylinder movements, but still by keeping a correct drag. The wing can obviously still be optimized.

# %% [markdown]
# # **Discussion**

# %% [markdown]
# A stabilized finite element method was implemented in FEniCS to solve the Navier-Stokes equations in 2D using an ALE finite element method. We used it to analyze a moving cylinder oscillating up and down, combined with a compression. We also analyzed a static cylinder, being deformed vertically in a cyclic way. Finally, we designed our own wing based also on a movement combined with a deformation of a cylinder. We added a x-component to the deformation in order to create assymetries in the cyclic movement and therefore create a positive average lift. When compared with the oscillating and static cylinders, we get a better lift as expected, and the drag is quite similar to the oscillating cylinder, and way better than the static cylinder, that was obviously dragging so much because of its x-projected dragging surface.
